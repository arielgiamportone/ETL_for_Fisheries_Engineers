# %% [markdown]
# # Configuración del Entorno para Análisis de Datos Pesqueros
#
# ## Introducción
# ¡Bienvenido a bordo! Antes de zarpar en nuestra aventura de datos pesqueros, necesitamos preparar nuestra embarcación (entorno de trabajo).
#
# ## Objetivos
# - Configurar el entorno Python necesario
# - Instalar las bibliotecas requeridas
# - Entender la estructura del proyecto
#
# ## Contenido
# 1. Instalación de dependencias
# 2. Importación de bibliotecas
# 3. Configuración de visualización
# 4. Verificación del entorno de trabajo

# %% [markdown]
# {
#  "cells": [
#   {
#    "cell_type": "markdown",
#    "metadata": {},
#    "source": [
#     "# Configuración del Entorno para Análisis de Datos Pesqueros 🎣\n",
#     "\n",
#     "## Introducción\n",
#     "¡Bienvenido a bordo, futuro científico de datos pesqueros! 🚢\n",
#     "\n",
#     "Antes de sumergirnos en el fascinante mundo del análisis de datos pesqueros, necesitamos preparar nuestro \"barco\" (entorno de trabajo). Este cuaderno te guiará paso a paso en la configuración de todas las herramientas necesarias para tu viaje de exploración de datos.\n",
#     "\n",
#     "## 1. Instalación de Python\n",
#     "\n",
#     "### 1.1 Descarga e Instalación de Python\n",
#     "1. Visita [python.org](https://www.python.org/downloads/)\n",
#     "2. Descarga Python 3.10.x (recomendamos esta versión para compatibilidad)\n",
#     "3. Durante la instalación:\n",
#     "   - ✅ Marca \"Add Python to PATH\"\n",
#     "   - ✅ Marca \"Install pip\"\n",
#     "\n",
#     "### 1.2 Verificación de la Instalación\n",
#     "Abre tu terminal (CMD en Windows) y ejecuta:"
#    ]
#   },
#   {
#    "cell_type": "code",
#    "execution_count": null,
#    "metadata": {},
#    "outputs": [],
#    "source": [
#     "# Verifica la versión de Python\n",
#     "!python --version\n",
#     "\n",
#     "# Verifica la versión de pip\n",
#     "!pip --version"
#    ]
#   },
#   {
#    "cell_type": "markdown",
#    "metadata": {},
#    "source": [
#     "## 2. Instalación de Jupyter Notebook/Lab\n",
#     "\n",
#     "Jupyter será nuestra \"bitácora de navegación\". Para instalarlo:"
#    ]
#   },
#   {
#    "cell_type": "code",
#    "execution_count": null,
#    "metadata": {},
#    "outputs": [],
#    "source": [
#     "# Instala Jupyter Lab\n",
#     "!pip install jupyterlab"
#    ]
#   },
#   {
#    "cell_type": "markdown",
#    "metadata": {},
#    "source": [
#     "## 3. Instalación de Dependencias\n",
#     "\n",
#     "Ahora instalaremos nuestras \"herramientas de pesca\" (bibliotecas). Estas son fundamentales para el análisis de datos:"
#    ]
#   },
#   {
#    "cell_type": "code",
#    "execution_count": null,
#    "metadata": {},
#    "outputs": [],
#    "source": [
#     "# Instalar las bibliotecas necesarias\n",
#     "!pip install pandas numpy matplotlib seaborn requests sqlalchemy"
#    ]
#   },
#   {
#    "cell_type": "markdown",
#    "metadata": {},
#    "source": [
#     "## 4. Verificación del Entorno\n",
#     "\n",
#     "Vamos a comprobar que todo está correctamente instalado:"
#    ]
#   },
#   {
#    "cell_type": "code",
#    "execution_count": null,
#    "metadata": {},
#    "outputs": [],
#    "source": [
#     "# Importamos las bibliotecas necesarias\n",
#     "import pandas as pd\n",
#     "import numpy as np\n",
#     "import matplotlib.pyplot as plt\n",
#     "import seaborn as sns\n",
#     "import requests\n",
#     "import sqlite3\n",
#     "from sqlalchemy import create_engine\n",
#     "\n",
#     "# Imprimimos las versiones\n",
#     "print(f\"Python version: {pd.__version__}\")\n",
#     "print(f\"Pandas version: {pd.__version__}\")\n",
#     "print(f\"NumPy version: {np.__version__}\")\n",
#     "print(f\"Matplotlib version: {plt.__version__}\")\n",
#     "print(f\"Seaborn version: {sns.__version__}\")"
#    ]
#   },
#   {
#    "cell_type": "markdown",
#    "metadata": {},
#    "source": [
#     "## 5. Configuración del Entorno de Visualización\n",
#     "\n",
#     "Configuraremos nuestras herramientas de visualización para obtener gráficos más atractivos:"
#    ]
#   },
#   {
#    "cell_type": "code",
#    "execution_count": null,
#    "metadata": {},
#    "outputs": [],
#    "source": [
#     "# Configuración de visualización\n",
#     "plt.rcParams['figure.figsize'] = (12, 6)\n",
#     "sns.set_theme(style=\"whitegrid\")\n",
#     "sns.set_palette(\"deep\")\n",
#     "\n",
#     "%matplotlib inline\n",
#     "\n",
#     "# Configuración para mostrar todas las columnas en pandas\n",
#     "pd.set_option('display.max_columns', None)"
#    ]
#   },
#   {
#    "cell_type": "markdown",
#    "metadata": {},
#    "source": [
#     "## 6. Estructura del Proyecto\n",
#     "\n",
#     "Nuestro proyecto está organizado de la siguiente manera:\n",
#     "\n",
#     "```\n",
#     "ETL_for_Fisheries_Engineers/\n",
#     "├── notebooks/                 # Cuadernos Jupyter\n",
#     "│   ├── 00_Configuracion_Entorno.ipynb        # ¡Estás aquí!\n",
#     "│   ├── 01_Extraccion_Tesoros_Datos.ipynb\n",
#     "│   ├── 02_Transformacion_Pulido_Gemas.ipynb\n",
#     "│   └── 03_Carga_Exhibicion_Hallazgos.ipynb\n",
#     "├── data/                     # Carpeta para datos\n",
#     "│   ├── raw/                  # Datos sin procesar\n",
#     "│   └── processed/            # Datos procesados\n",
#     "└── src/                      # Código fuente\n",
#     "    ├── data_utils.py         # Utilidades para datos\n",
#     "    └── processing.py         # Funciones de procesamiento\n",
#     "```\n",
#     "\n",
#     "## 7. ¡Listo para Zarpar! 🚢\n",
#     "\n",
#     "¡Felicitaciones! Has configurado exitosamente tu entorno de trabajo. Ahora estás listo para comenzar tu viaje en el análisis de datos pesqueros. En los siguientes cuadernos, aprenderás a:\n",
#     "\n",
#     "1. Extraer datos de diferentes fuentes\n",
#     "2. Transformar y limpiar los datos\n",
#     "3. Cargar y visualizar los resultados\n",
#     "\n",
#     "**Próximo paso:** Dirígete al cuaderno `01_Extraccion_Tesoros_Datos.ipynb` para comenzar con la extracción de datos."
#    ]
#   }
#  ],
#  "metadata": {
#   "language_info": {
#    "name": "python"
#   }
#  },
#  "nbformat": 4,
#  "nbformat_minor": 2
# }
